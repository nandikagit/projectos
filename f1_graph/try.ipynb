# %%
import pandas as pd
from func import get_curr_standings_espn, join_espn_output,joined_df_col_renames, convert_to_numeric, plot_points, plot_points_over_races

# %%
# reading data from site
year:int = 2024
tables: list[pd.DataFrame] = get_curr_standings_espn(year)
df_joined: pd.DataFrame = join_espn_output(tables)
df_col_renamed: pd.DataFrame = joined_df_col_renames(df_joined)
df_numeric: pd.DataFrame = convert_to_numeric(df_col_renamed)

# %%
plot_points(df_numeric, year, "green", "indigo")

# %%
plot_points_over_races(df_numeric, year,10,5)
